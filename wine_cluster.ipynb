# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
from sklearn.decomposition import PCA

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ML datasets/wine-clustering.csv')

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
def normalise(df,cols=[]):
    for col in cols:
        df[col] = (df[col] - df[col].mean())/df[col].std()
    return df

# %%
df_norm = normalise(df, df.columns)

# %%
df_norm
# Out:
#       Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    1.514341   -0.560668  0.231400     -1.166303   1.908522       0.806722
# 1    0.245597   -0.498009 -0.825667     -2.483841   0.018094       0.567048
# 2    0.196325    0.021172  1.106214     -0.267982   0.088110       0.806722
# 3    1.686791   -0.345835  0.486554     -0.806975   0.928300       2.484437
# 4    0.294868    0.227053  1.835226      0.450674   1.278379       0.806722
# ..        ...         ...       ...           ...        ...            ...
# 173  0.873810    2.966176  0.304301      0.300954  -0.331985      -0.982841
# 174  0.491955    1.408636  0.413653      1.049555   0.158126      -0.791103
# 175  0.331822    1.739837 -0.388260      0.151234   1.418411      -1.126646
# 176  0.208643    0.227053  0.012696      0.151234   1.418411      -1.030776
# 177  1.391162    1.578712  1.361368      1.498716  -0.261969      -0.391646
#
# ...

# %%
scores= []
for i in range(2,11):
    kmean = KMeans(n_clusters=i, n_init='auto', random_state=42)
    clusters = kmean.fit_predict(df_norm)
    silhoutte = silhouette_score(df_norm, clusters)
    scores.append(silhoutte)

# %%
np.argmax(scores)
# Out:
# 1

# %%
plt.plot(range(2,11), scores, marker='x', )

# %%
kmean = KMeans(n_clusters=3, n_init='auto',random_state=42)

pca = PCA(2)

pca_df = pc.fit_transform(df_norm)

pred = kmean.fit_predict(pca_df)
center = kmean.cluster_centers_

# %%
for i in np.unique(pred):
    plt.scatter(pca_df[pred==i, 0], pca_df[pred==i, 1], label=f'Cluster{i}')
plt.scatter(center[:,0], center[:,1], color='k')
plt.show()
